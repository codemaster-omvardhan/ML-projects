# %% [markdown]
# <a href="https://colab.research.google.com/github/codemaster-omvardhan/ML-projects/blob/main/Copy_of_Olympics_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from google.colab import files

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('athlete_events.csv')
region_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/country_definitions.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2684941641.py in <cell line: 0>()
# ----> 1 df = pd.read_csv('athlete_events.csv')
#       2 region_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/country_definitions.csv')
#
# ...

# %%
df.head(2)

# %%
df.shape

# %%
df = df[df['Season'] == 'Summer']

# %%
df.shape

# %%
region_df.tail()

# %%
df = df.merge(region_df,on='NOC',how='left')

# %%
df.tail()

# %%
df['region'].unique()

# %%
df.isnull().sum()

# %%
df.duplicated().sum()

# %%
df.drop_duplicates(inplace=True)
